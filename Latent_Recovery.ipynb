# %%
# Setup :)
import numpy as np
import time
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
tf.enable_eager_execution(config=config)

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Flatten, Conv3D, Dense, Conv1D, Input, Reshape, Conv3DTranspose, BatchNormalization
from tensorflow.keras.losses import logcosh
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow import GradientTape
from tensorflow.train import Saver
from tensorflow import Session
from tensorflow.train import AdamOptimizer

# Use Adam optimizer.
optimizer = AdamOptimizer(1e-4)

# %%
# Creates autoencoder 
########################## ENCODER NETWORK #################################
# Input is 32x32x32 point cloud
voxel_input = Input(shape=(32, 32, 32, 1))

# First convolutional layer: outputs 30x30x30
encode_c1 = Conv3D(8, kernel_size=3, activation='elu', padding='valid',
              data_format='channels_last', kernel_regularizer=l2(l=0.01))(voxel_input)
encode_b1 = BatchNormalization()(encode_c1)

# Second convolutional layer: outputs 15x15x15 (downsamples via striding)
encode_c2 = Conv3D(16, kernel_size=3, activation='elu', padding='same',
              strides=(2, 2, 2), kernel_regularizer=l2(l=0.01))(encode_b1)
encode_b2 = BatchNormalization()(encode_c2)

# Third convolutional layer: outputs 13x13x13
encode_c3 = Conv3D(32, kernel_size=3, activation='elu', padding='valid',
                  kernel_regularizer=l2(l=0.01))(encode_b2)
encode_b3 = BatchNormalization()(encode_c3)

# Fourth convolutional layer: outputs 7x7x7 (downsamples via striding)
encode_c4 = Conv3D(64, kernel_size=3, activation='elu', padding='same',
              strides=(2, 2, 2), kernel_regularizer=l2(l=0.01))(encode_b3)
encode_b4 = BatchNormalization()(encode_c4)

# Fifth layer, fully connected: outputs 343
encode_f5 = Flatten()(encode_b4)
encode_b5 = BatchNormalization()(encode_f5)

# Sixth layer - LATENT LAYER: outputs 100
latent = Dense(100, use_bias=True, activation='elu',
               kernel_regularizer=l2(l=0.01))(encode_b5)

encoder = Model(inputs=voxel_input, outputs=latent)

# Run this to get summary of encoder's layers
# encoder.summary()


########################## DECODER NETWORK #################################
# Latent space of 1D dimension 100 is input for decoder
decoder_input = Input(shape=(100,))

# First layer of decoder, fully connected layer: outputs 343
decode_f1 = Dense(343, use_bias=True, activation='elu',
                 kernel_regularizer=l2(l=0.01))(decoder_input)
decode_b1 = BatchNormalization()(decode_f1)

# Reshape layer from fully connected to 7x7x7
# must add spacial dimension for convolutions to work
decode_reshape = Reshape((7, 7, 7, 1), input_shape=(343,))(decode_b1)

# Second convolutional layer: convolutes fully connected layer into 7x7x7
decode_c2 = Conv3D(64, kernel_size=3, activation='elu',
                   padding='same', kernel_regularizer=l2(l=0.01))(decode_reshape)
decode_b2 = BatchNormalization()(decode_c2)

# Third layer (second convolutional layer): outputs 15x15x15
decode_c3 = Conv3DTranspose(32, kernel_size=3, activation='elu',padding='valid',
                   strides=(2, 2, 2), kernel_regularizer=l2(l=0.01))(decode_b2)
decode_b3 = BatchNormalization()(decode_c3)

# Fourth convolutional layer: outputs 15x15x15
decode_c4 = Conv3DTranspose(16, kernel_size=3, activation='elu',
                   padding='same', kernel_regularizer=l2(l=0.01))(decode_b3)
decode_b4 = BatchNormalization()(decode_c4)

# Fifth convolutional layer: outputs 32x32x32
decode_c5 = Conv3DTranspose(8, kernel_size=3, activation='elu', padding='valid',
                   strides=(2, 2, 2), output_padding=1, kernel_regularizer=l2(l=0.01))(decode_b4)
decode_b5 = BatchNormalization()(decode_c5)

# OUTPUT LAYERRRRRRRR!!! Sigmoid function to output probability each voxel is filled
decode_output = Conv3DTranspose(1, kernel_size=3, activation='sigmoid',
                   padding='same', kernel_regularizer=l2(l=0.01))(decode_b5)

decoder = Model(inputs=decoder_input, outputs=decode_output)

# Run this to get layer summary for decode_reshape
# decoder.summary()

################################# AUTOENCODER ###############################
reconstruction = decoder(encoder(voxel_input))
ae = Model(inputs=voxel_input, outputs=reconstruction)

ae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 32, 32, 32, 1)     0
# _________________________________________________________________
# model_6 (Model)              (None, 100)               2356500
# _________________________________________________________________
# model_7 (Model)              (None, 32, 32, 32, 1)     111136
# =================================================================
# Total params: 2,467,636
# Trainable params: 2,422,566
# Non-trainable params: 45,070
# _________________________________________________________________

# %%
# Load already trained weights 
model_checkpoint_file = 'ae_checkpoint'
ae.load_weights(model_checkpoint_file)

# Get Decoder portion of AE
decoder = ae.layers[2]
decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 343)               34643
# _________________________________________________________________
# batch_normalization_v1_25 (B (None, 343)               1372
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 7, 7, 7, 1)        0
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 7, 7, 7, 64)       1792
# _________________________________________________________________
# batch_normalization_v1_26 (B (None, 7, 7, 7, 64)       256
# _________________________________________________________________
# conv3d_transpose_8 (Conv3DTr (None, 15, 15, 15, 32)    55328
# _________________________________________________________________
# batch_normalization_v1_27 (B (None, 15, 15, 15, 32)    128
# _________________________________________________________________
# conv3d_transpose_9 (Conv3DTr (None, 15, 15, 15, 16)    13840
# _________________________________________________________________
# batch_normalization_v1_28 (B (None, 15, 15, 15, 16)    64
# _________________________________________________________________
# conv3d_transpose_10 (Conv3DT (None, 32, 32, 32, 8)     3464
# _________________________________________________________________
# batch_normalization_v1_29 (B (None, 32, 32, 32, 8)     32
# _________________________________________________________________
# conv3d_transpose_11 (Conv3DT (None, 32, 32, 32, 1)     217
# =================================================================
# Total params: 111,136
# Trainable params: 110,210
# Non-trainable params: 926
# _________________________________________________________________

# %%
################### MODIFIED BINARY CROSS ENTROPY LOSS FUNCTION ############
# Binary cross entropy but with value clamping
def lambda_binary_crossentropy(y_true, y_pred):
  # Only want loss from the voxels that are present in the partial
#   y_pred = tf.math.multiply(y_true, y_pred)
  
  y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)
  binary_entr = y_true*((-y_true * tf.log(y_pred)) - ((1.0-y_true) * tf.log(1.0-y_pred)))

  # getting tensor values into scalar
  loss = tf.reduce_sum(binary_entr, axis=1)
  scalar_loss = tf.reduce_mean(loss)

  return scalar_loss

# %%
# Gradient computation with given model, input latent space, and partial voxel
def compute_gradients(model, latent, partial):
#   input_tensor = tf.cast(x[0], dtype=tf.float32)
  with GradientTape() as tape:
    tape.watch(latent)
    y = model(latent)
    loss = lambda_binary_crossentropy(partial, y)
    
    # model.trainable_variables
    #????? loss is scalar? how is it the gradient target? 
    return tape.gradient(loss, latent), loss
 
# 
# "Generates" a latent space by passing an initially random latent vector
# through the decoder netowrk, and computing loss between 
# decoder's output and a partial view voxel.
#
# Runs updates until loss is under loss_thresh
#
def recover_latent(partial, loss_thresh):
  # Latent vector starts as a random vector
  curr_latent = tf.random.uniform(shape=(1, 100))
  curr_latent = tf.Variable(curr_latent)
  
  loss = float('inf')
  iter = 0
  while loss > loss_thresh:
    print 'Iteration: ', str(iter)
    # Compute gradient and loss of current latent vector
    gradients, loss = compute_gradients(decoder, curr_latent, partial)
    print loss
    gradients = tf.reshape(gradients, (1, 100))
    
    # Updating latent vector according to gradient
    optimizer.apply_gradients(zip([gradients], [curr_latent])) 
    iter += 1

# %%
# Testing on dummy voxel 
dummy_vox = tf.random.uniform(shape=(32, 32, 32))

recover_latent(dummy_vox, 10.0)
# Out:
# Iteration:  0
# tf.Tensor(160.90533, shape=(), dtype=float32)
# Iteration:  1
# tf.Tensor(160.90417, shape=(), dtype=float32)
# Iteration:  2
# tf.Tensor(160.90233, shape=(), dtype=float32)
# Iteration:  3
# tf.Tensor(160.9013, shape=(), dtype=float32)
# Iteration:  4
# tf.Tensor(160.90292, shape=(), dtype=float32)
# Iteration:  5
# tf.Tensor(160.8974, shape=(), dtype=float32)
# Iteration:  6
# tf.Tensor(160.89789, shape=(), dtype=float32)
# Iteration:  7
# tf.Tensor(160.89932, shape=(), dtype=float32)
# Iteration:  8
# tf.Tensor(160.89276, shape=(), dtype=float32)
# Iteration:  9
# tf.Tensor(160.89258, shape=(), dtype=float32)
# Iteration:  10
# tf.Tensor(160.89026, shape=(), dtype=float32)
# Iteration:  11
# tf.Tensor(160.88947, shape=(), dtype=float32)
# Iteration:  12
# tf.Tensor(160.87856, shape=(), dtype=float32)
# Iteration:  13
# tf.Tensor(160.88065, shape=(), dtype=float32)
# Iteration:  14
# tf.Tensor(160.8805, shape=(), dtype=float32)
# Iteration:  15
# tf.Tensor(160.88354, shape=(), dtype=float32)
# Iteration:  16
# tf.Tensor(160.87442, shape=(), dtype=float32)
# Iteration:  17
# tf.Tensor(160.87386, shape=(), dtype=float32)
# Iteration:  18
# tf.Tensor(160.87439, shape=(), dtype=float32)
# Iteration:  19
# tf.Tensor(160.87074, shape=(), dtype=float32)
# Iteration:  20
# tf.Tensor(160.86841, shape=(), dtype=float32)
# Iteration:  21
# tf.Tensor(160.86633, shape=(), dtype=float32)
# Iteration:  22
# tf.Tensor(160.8661, shape=(), dtype=float32)
# Iteration:  23
# tf.Tensor(160.85901, shape=(), dtype=float32)
# Iteration:  24
# tf.Tensor(160.85812, shape=(), dtype=float32)
# Iteration:  25
# tf.Tensor(160.85818, shape=(), dtype=float32)
# Iteration:  26
# tf.Tensor(160.85808, shape=(), dtype=float32)
# Iteration:  27
# tf.Tensor(160.85727, shape=(), dtype=float32)
# Iteration:  28
# tf.Tensor(160.85489, shape=(), dtype=float32)
# Iteration:  29
# tf.Tensor(160.8512, shape=(), dtype=float32)
# Iteration:  30
# tf.Tensor(160.84726, shape=(), dtype=float32)
# Iteration:  31
# tf.Tensor(160.84647, shape=(), dtype=float32)
# Iteration:  32
# tf.Tensor(160.84763, shape=(), dtype=float32)
# Iteration:  33
# tf.Tensor(160.84393, shape=(), dtype=float32)
# Iteration:  34
# tf.Tensor(160.84195, shape=(), dtype=float32)
# Iteration:  35
# tf.Tensor(160.84265, shape=(), dtype=float32)
# Iteration:  36
# tf.Tensor(160.8389, shape=(), dtype=float32)
# Iteration:  37
# tf.Tensor(160.83891, shape=(), dtype=float32)
# Iteration:  38
# tf.Tensor(160.83649, shape=(), dtype=float32)
# Iteration:  39
# tf.Tensor(160.8313, shape=(), dtype=float32)
# Iteration:  40
# tf.Tensor(160.82935, shape=(), dtype=float32)
# Iteration:  41
# tf.Tensor(160.83023, shape=(), dtype=float32)
# Iteration:  42
# tf.Tensor(160.83044, shape=(), dtype=float32)
# Iteration:  43
# tf.Tensor(160.82712, shape=(), dtype=float32)
# Iteration:  44
# tf.Tensor(160.8235, shape=(), dtype=float32)
# Iteration:  45
# tf.Tensor(160.82332, shape=(), dtype=float32)
# Iteration:  46
# tf.Tensor(160.82153, shape=(), dtype=float32)
# Iteration:  47
# tf.Tensor(160.82181, shape=(), dtype=float32)
# Iteration:  48
# tf.Tensor(160.81972, shape=(), dtype=float32)
# Iteration:  49
# tf.Tensor(160.8188, shape=(), dtype=float32)
# Iteration:  50
# tf.Tensor(160.81409, shape=(), dtype=float32)
# Iteration:  51
# tf.Tensor(160.81628, shape=(), dtype=float32)
# Iteration:  52
# tf.Tensor(160.81181, shape=(), dtype=float32)
# Iteration:  53
# tf.Tensor(160.80856, shape=(), dtype=float32)
# Iteration:  54
# tf.Tensor(160.80933, shape=(), dtype=float32)
# Iteration:  55
# tf.Tensor(160.80736, shape=(), dtype=float32)
# Iteration:  56
# tf.Tensor(160.8096, shape=(), dtype=float32)
# Iteration:  57
# tf.Tensor(160.80788, shape=(), dtype=float32)
# Iteration:  58
# tf.Tensor(160.80396, shape=(), dtype=float32)
# Iteration:  59
# tf.Tensor(160.80148, shape=(), dtype=float32)
# Iteration:  60
# tf.Tensor(160.7994, shape=(), dtype=float32)
# Iteration:  61
# tf.Tensor(160.80408, shape=(), dtype=float32)
# Iteration:  62
# tf.Tensor(160.79898, shape=(), dtype=float32)
# Iteration:  63
# tf.Tensor(160.79515, shape=(), dtype=float32)
# Iteration:  64
# tf.Tensor(160.79501, shape=(), dtype=float32)
# Iteration:  65
# tf.Tensor(160.79616, shape=(), dtype=float32)
# Iteration:  66
# tf.Tensor(160.79187, shape=(), dtype=float32)
# Iteration:  67
# tf.Tensor(160.79312, shape=(), dtype=float32)
# Iteration:  68
# tf.Tensor(160.7893, shape=(), dtype=float32)
# Iteration:  69
# tf.Tensor(160.78531, shape=(), dtype=float32)
# Iteration:  70
# tf.Tensor(160.78607, shape=(), dtype=float32)
# Iteration:  71
# tf.Tensor(160.78528, shape=(), dtype=float32)
# Iteration:  72
# tf.Tensor(160.7836, shape=(), dtype=float32)
# Iteration:  73
# tf.Tensor(160.78395, shape=(), dtype=float32)
# Iteration:  74
# tf.Tensor(160.78336, shape=(), dtype=float32)
# Iteration:  75
# tf.Tensor(160.78162, shape=(), dtype=float32)
# Iteration:  76
# tf.Tensor(160.77718, shape=(), dtype=float32)
# Iteration:  77
# tf.Tensor(160.77962, shape=(), dtype=float32)
# Iteration:  78
# tf.Tensor(160.77435, shape=(), dtype=float32)
# Iteration:  79
# tf.Tensor(160.77452, shape=(), dtype=float32)
# Iteration:  80
# tf.Tensor(160.77591, shape=(), dtype=float32)
# Iteration:  81
# tf.Tensor(160.77057, shape=(), dtype=float32)
# Iteration:  82
# tf.Tensor(160.77423, shape=(), dtype=float32)
# Iteration:  83
# tf.Tensor(160.76733, shape=(), dtype=float32)
# Iteration:  84
# tf.Tensor(160.7663, shape=(), dtype=float32)
# Iteration:  85
# tf.Tensor(160.76607, shape=(), dtype=float32)
# Iteration:  86
# tf.Tensor(160.76634, shape=(), dtype=float32)
# Iteration:  87
# tf.Tensor(160.76639, shape=(), dtype=float32)
# Iteration:  88
# tf.Tensor(160.76355, shape=(), dtype=float32)
# Iteration:  89
# tf.Tensor(160.76433, shape=(), dtype=float32)
# Iteration:  90
# tf.Tensor(160.75845, shape=(), dtype=float32)
# Iteration:  91
# tf.Tensor(160.76282, shape=(), dtype=float32)
# Iteration:  92
# tf.Tensor(160.76074, shape=(), dtype=float32)
# Iteration:  93
# tf.Tensor(160.75714, shape=(), dtype=float32)
# Iteration:  94
# tf.Tensor(160.75574, shape=(), dtype=float32)
# Iteration:  95
# tf.Tensor(160.75406, shape=(), dtype=float32)
# Iteration:  96
# tf.Tensor(160.7533, shape=(), dtype=float32)
# Iteration:  97
# tf.Tensor(160.75008, shape=(), dtype=float32)
# Iteration:  98
# tf.Tensor(160.74858, shape=(), dtype=float32)
# Iteration:  99
# tf.Tensor(160.74765, shape=(), dtype=float32)
# Iteration:  100
# tf.Tensor(160.7518, shape=(), dtype=float32)
# Iteration:  101
# tf.Tensor(160.74396, shape=(), dtype=float32)
# Iteration:  102
# tf.Tensor(160.74902, shape=(), dtype=float32)
# Iteration:  103
# tf.Tensor(160.74756, shape=(), dtype=float32)
# Iteration:  104
# tf.Tensor(160.74408, shape=(), dtype=float32)
# Iteration:  105
# tf.Tensor(160.74353, shape=(), dtype=float32)
# Iteration:  106
# tf.Tensor(160.74127, shape=(), dtype=float32)
# Iteration:  107
# tf.Tensor(160.74165, shape=(), dtype=float32)
# Iteration:  108
# tf.Tensor(160.73834, shape=(), dtype=float32)
# Iteration:  109
# tf.Tensor(160.73364, shape=(), dtype=float32)
# Iteration:  110
# tf.Tensor(160.73438, shape=(), dtype=float32)
# Iteration:  111
# tf.Tensor(160.73431, shape=(), dtype=float32)
# Iteration:  112
# tf.Tensor(160.73239, shape=(), dtype=float32)
# Iteration:  113
# tf.Tensor(160.72899, shape=(), dtype=float32)
# Iteration:  114
# tf.Tensor(160.73341, shape=(), dtype=float32)
# Iteration:  115
# tf.Tensor(160.73465, shape=(), dtype=float32)
# Iteration:  116
# tf.Tensor(160.73068, shape=(), dtype=float32)
# Iteration:  117
# tf.Tensor(160.73193, shape=(), dtype=float32)
# Iteration:  118
# tf.Tensor(160.72853, shape=(), dtype=float32)
# Iteration:  119
# tf.Tensor(160.72516, shape=(), dtype=float32)
# Iteration:  120
# tf.Tensor(160.72012, shape=(), dtype=float32)
# Iteration:  121
# tf.Tensor(160.7235, shape=(), dtype=float32)
# Iteration:  122
# tf.Tensor(160.71869, shape=(), dtype=float32)
# Iteration:  123
# tf.Tensor(160.71829, shape=(), dtype=float32)
# Iteration:  124
# tf.Tensor(160.71802, shape=(), dtype=float32)
# Iteration:  125
# tf.Tensor(160.71394, shape=(), dtype=float32)
# Iteration:  126
# tf.Tensor(160.71634, shape=(), dtype=float32)
# Iteration:  127
# tf.Tensor(160.71771, shape=(), dtype=float32)
# Iteration:  128
# tf.Tensor(160.71584, shape=(), dtype=float32)
# Iteration:  129
# tf.Tensor(160.71207, shape=(), dtype=float32)
# Iteration:  130
# tf.Tensor(160.71286, shape=(), dtype=float32)
# Iteration:  131
# tf.Tensor(160.71063, shape=(), dtype=float32)
# Iteration:  132
# tf.Tensor(160.70992, shape=(), dtype=float32)
# Iteration:  133
# tf.Tensor(160.70505, shape=(), dtype=float32)
# Iteration:  134
# tf.Tensor(160.70602, shape=(), dtype=float32)
# Iteration:  135
# tf.Tensor(160.7068, shape=(), dtype=float32)
# Iteration:  136
# tf.Tensor(160.70499, shape=(), dtype=float32)
# Iteration:  137
# tf.Tensor(160.70425, shape=(), dtype=float32)
# Iteration:  138
# tf.Tensor(160.70181, shape=(), dtype=float32)
# Iteration:  139
# tf.Tensor(160.70181, shape=(), dtype=float32)
# Iteration:  140
# tf.Tensor(160.70126, shape=(), dtype=float32)
# Iteration:  141
# tf.Tensor(160.69885, shape=(), dtype=float32)
# Iteration:  142
# tf.Tensor(160.69724, shape=(), dtype=float32)
# Iteration:  143
# tf.Tensor(160.69533, shape=(), dtype=float32)
# Iteration:  144
# tf.Tensor(160.6939, shape=(), dtype=float32)
# Iteration:  145
# tf.Tensor(160.6936, shape=(), dtype=float32)
# Iteration:  146
# tf.Tensor(160.6901, shape=(), dtype=float32)
# Iteration:  147
# tf.Tensor(160.68993, shape=(), dtype=float32)
# Iteration:  148
# tf.Tensor(160.69312, shape=(), dtype=float32)
# Iteration:  149
# tf.Tensor(160.68983, shape=(), dtype=float32)
# Iteration:  150
# tf.Tensor(160.68741, shape=(), dtype=float32)
# Iteration:  151
# tf.Tensor(160.68468, shape=(), dtype=float32)
# Iteration:  152
# tf.Tensor(160.68565, shape=(), dtype=float32)
# Iteration:  153
# tf.Tensor(160.68475, shape=(), dtype=float32)
# Iteration:  154
# tf.Tensor(160.68292, shape=(), dtype=float32)
# Iteration:  155
# tf.Tensor(160.68521, shape=(), dtype=float32)
# Iteration:  156
# tf.Tensor(160.68408, shape=(), dtype=float32)
# Iteration:  157
# tf.Tensor(160.68, shape=(), dtype=float32)
# Iteration:  158
# tf.Tensor(160.67828, shape=(), dtype=float32)
# Iteration:  159
# tf.Tensor(160.68329, shape=(), dtype=float32)
# Iteration:  160
# tf.Tensor(160.68015, shape=(), dtype=float32)
# Iteration:  161
# tf.Tensor(160.67648, shape=(), dtype=float32)
# Iteration:  162
# tf.Tensor(160.67468, shape=(), dtype=float32)
# Iteration:  163
# tf.Tensor(160.67426, shape=(), dtype=float32)
# Iteration:  164
# tf.Tensor(160.6737, shape=(), dtype=float32)
# Iteration:  165
# tf.Tensor(160.67522, shape=(), dtype=float32)
# Iteration:  166
# tf.Tensor(160.67386, shape=(), dtype=float32)
# Iteration:  167
# tf.Tensor(160.67105, shape=(), dtype=float32)
# Iteration:  168
# tf.Tensor(160.66711, shape=(), dtype=float32)
# Iteration:  169
# tf.Tensor(160.66492, shape=(), dtype=float32)
# Iteration:  170
# tf.Tensor(160.66537, shape=(), dtype=float32)
# Iteration:  171
# tf.Tensor(160.66722, shape=(), dtype=float32)
# Iteration:  172
# tf.Tensor(160.66086, shape=(), dtype=float32)
# Iteration:  173
# tf.Tensor(160.66318, shape=(), dtype=float32)
# Iteration:  174
# tf.Tensor(160.66171, shape=(), dtype=float32)
# Iteration:  175
# tf.Tensor(160.65974, shape=(), dtype=float32)
# Iteration:  176
# tf.Tensor(160.65729, shape=(), dtype=float32)
# Iteration:  177
# tf.Tensor(160.65778, shape=(), dtype=float32)
# Iteration:  178
# tf.Tensor(160.6604, shape=(), dtype=float32)
# Iteration:  179
# tf.Tensor(160.65833, shape=(), dtype=float32)
# Iteration:  180
# tf.Tensor(160.65846, shape=(), dtype=float32)
# Iteration:  181
# tf.Tensor(160.65302, shape=(), dtype=float32)
# Iteration:  182
# tf.Tensor(160.65445, shape=(), dtype=float32)
# Iteration:  183
# tf.Tensor(160.65276, shape=(), dtype=float32)
# Iteration:  184
# tf.Tensor(160.65222, shape=(), dtype=float32)
# Iteration:  185
# tf.Tensor(160.64957, shape=(), dtype=float32)
# Iteration:  186
# tf.Tensor(160.65291, shape=(), dtype=float32)
# Iteration:  187
# tf.Tensor(160.64914, shape=(), dtype=float32)
# Iteration:  188
# tf.Tensor(160.6485, shape=(), dtype=float32)
# Iteration:  189
# tf.Tensor(160.64511, shape=(), dtype=float32)
# Iteration:  190
# tf.Tensor(160.64386, shape=(), dtype=float32)
# Iteration:  191
# tf.Tensor(160.64413, shape=(), dtype=float32)
# Iteration:  192
# tf.Tensor(160.64447, shape=(), dtype=float32)
# Iteration:  193
# tf.Tensor(160.63676, shape=(), dtype=float32)
# Iteration:  194
# tf.Tensor(160.63959, shape=(), dtype=float32)
# Iteration:  195
# tf.Tensor(160.63783, shape=(), dtype=float32)
# Iteration:  196
# tf.Tensor(160.63997, shape=(), dtype=float32)
# Iteration:  197
# tf.Tensor(160.63228, shape=(), dtype=float32)
# Iteration:  198
# tf.Tensor(160.63326, shape=(), dtype=float32)
# Iteration:  199
# tf.Tensor(160.63426, shape=(), dtype=float32)
# Iteration:  200
# tf.Tensor(160.63202, shape=(), dtype=float32)
# Iteration:  201
# tf.Tensor(160.63344, shape=(), dtype=float32)
# Iteration:  202
# tf.Tensor(160.62881, shape=(), dtype=float32)
# Iteration:  203
# tf.Tensor(160.63358, shape=(), dtype=float32)
# Iteration:  204
# tf.Tensor(160.62811, shape=(), dtype=float32)
# Iteration:  205
# tf.Tensor(160.6285, shape=(), dtype=float32)
# Iteration:  206
# tf.Tensor(160.62772, shape=(), dtype=float32)
# Iteration:  207
# tf.Tensor(160.62598, shape=(), dtype=float32)
# Iteration:  208
# tf.Tensor(160.6247, shape=(), dtype=float32)
# Iteration:  209
# tf.Tensor(160.62335, shape=(), dtype=float32)
# Iteration:  210
# tf.Tensor(160.62428, shape=(), dtype=float32)
# Iteration:  211
# tf.Tensor(160.62088, shape=(), dtype=float32)
# Iteration:  212
# tf.Tensor(160.62146, shape=(), dtype=float32)
# Iteration:  213
# tf.Tensor(160.62221, shape=(), dtype=float32)
# Iteration:  214
# tf.Tensor(160.61914, shape=(), dtype=float32)
# Iteration:  215
# tf.Tensor(160.61673, shape=(), dtype=float32)
# Iteration:  216
# tf.Tensor(160.61823, shape=(), dtype=float32)
# Iteration:  217
# tf.Tensor(160.61484, shape=(), dtype=float32)
# Iteration:  218
# tf.Tensor(160.61404, shape=(), dtype=float32)
# Iteration:  219
# tf.Tensor(160.61264, shape=(), dtype=float32)
# Iteration:  220
# tf.Tensor(160.61276, shape=(), dtype=float32)
# Iteration:  221
# tf.Tensor(160.6104, shape=(), dtype=float32)
# Iteration:  222
# tf.Tensor(160.60849, shape=(), dtype=float32)
# Iteration:  223
# tf.Tensor(160.61234, shape=(), dtype=float32)
# Iteration:  224
# tf.Tensor(160.60928, shape=(), dtype=float32)
# Iteration:  225
# tf.Tensor(160.60745, shape=(), dtype=float32)
# Iteration:  226
# tf.Tensor(160.60951, shape=(), dtype=float32)
# Iteration:  227
# tf.Tensor(160.60602, shape=(), dtype=float32)
# Iteration:  228
# tf.Tensor(160.60538, shape=(), dtype=float32)
# Iteration:  229
# tf.Tensor(160.6026, shape=(), dtype=float32)
# Iteration:  230
# tf.Tensor(160.60388, shape=(), dtype=float32)
# Iteration:  231
# tf.Tensor(160.59859, shape=(), dtype=float32)
# Iteration:  232
# tf.Tensor(160.59929, shape=(), dtype=float32)
# Iteration:  233
# tf.Tensor(160.60008, shape=(), dtype=float32)
# Iteration:  234
# tf.Tensor(160.6001, shape=(), dtype=float32)
# Iteration:  235
# tf.Tensor(160.59714, shape=(), dtype=float32)
# Iteration:  236
# tf.Tensor(160.59952, shape=(), dtype=float32)
# Iteration:  237
# tf.Tensor(160.59576, shape=(), dtype=float32)
# Iteration:  238
# tf.Tensor(160.59338, shape=(), dtype=float32)
# Iteration:  239
# tf.Tensor(160.59354, shape=(), dtype=float32)
# Iteration:  240
# tf.Tensor(160.59256, shape=(), dtype=float32)
# Iteration:  241
# tf.Tensor(160.59106, shape=(), dtype=float32)
# Iteration:  242
# tf.Tensor(160.5892, shape=(), dtype=float32)
# Iteration:  243
# tf.Tensor(160.58849, shape=(), dtype=float32)
# Iteration:  244
# tf.Tensor(160.59044, shape=(), dtype=float32)
# Iteration:  245
# tf.Tensor(160.58655, shape=(), dtype=float32)
# Iteration:  246
# tf.Tensor(160.58667, shape=(), dtype=float32)
# Iteration:  247
# tf.Tensor(160.58301, shape=(), dtype=float32)
# Iteration:  248
# tf.Tensor(160.58548, shape=(), dtype=float32)
# Iteration:  249
# tf.Tensor(160.58223, shape=(), dtype=float32)
# Iteration:  250
# tf.Tensor(160.58102, shape=(), dtype=float32)
# Iteration:  251
# tf.Tensor(160.58443, shape=(), dtype=float32)
# Iteration:  252
# tf.Tensor(160.58167, shape=(), dtype=float32)
# Iteration:  253
# tf.Tensor(160.57938, shape=(), dtype=float32)
# Iteration:  254
# tf.Tensor(160.57846, shape=(), dtype=float32)
# Iteration:  255
# tf.Tensor(160.57622, shape=(), dtype=float32)
# Iteration:  256
# tf.Tensor(160.57646, shape=(), dtype=float32)
# Iteration:  257
# tf.Tensor(160.57153, shape=(), dtype=float32)
# Iteration:  258
# tf.Tensor(160.57538, shape=(), dtype=float32)
# Iteration:  259
# tf.Tensor(160.57278, shape=(), dtype=float32)
# Iteration:  260
# tf.Tensor(160.57141, shape=(), dtype=float32)
# Iteration:  261
# tf.Tensor(160.56804, shape=(), dtype=float32)
# Iteration:  262
# tf.Tensor(160.56874, shape=(), dtype=float32)
# Iteration:  263
# tf.Tensor(160.56586, shape=(), dtype=float32)
# Iteration:  264
# tf.Tensor(160.56538, shape=(), dtype=float32)
# Iteration:  265
# tf.Tensor(160.56873, shape=(), dtype=float32)
# Iteration:  266
# tf.Tensor(160.56729, shape=(), dtype=float32)
# Iteration:  267
# tf.Tensor(160.56311, shape=(), dtype=float32)
# Iteration:  268
# tf.Tensor(160.56519, shape=(), dtype=float32)
# Iteration:  269
# tf.Tensor(160.56142, shape=(), dtype=float32)
# Iteration:  270
# tf.Tensor(160.56073, shape=(), dtype=float32)
# Iteration:  271
# tf.Tensor(160.55899, shape=(), dtype=float32)
# Iteration:  272
# tf.Tensor(160.55762, shape=(), dtype=float32)
# Iteration:  273
# tf.Tensor(160.55615, shape=(), dtype=float32)
# Iteration:  274
# tf.Tensor(160.55392, shape=(), dtype=float32)
# Iteration:  275
# tf.Tensor(160.5573, shape=(), dtype=float32)
# Iteration:  276
# tf.Tensor(160.55286, shape=(), dtype=float32)
# Iteration:  277
# tf.Tensor(160.55551, shape=(), dtype=float32)
# Iteration:  278
# tf.Tensor(160.55597, shape=(), dtype=float32)
# Iteration:  279
# tf.Tensor(160.55157, shape=(), dtype=float32)
# Iteration:  280
# tf.Tensor(160.5509, shape=(), dtype=float32)
# Iteration:  281
# tf.Tensor(160.54805, shape=(), dtype=float32)
# Iteration:  282
# tf.Tensor(160.54918, shape=(), dtype=float32)
# Iteration:  283
# tf.Tensor(160.5455, shape=(), dtype=float32)
# Iteration:  284
# tf.Tensor(160.5468, shape=(), dtype=float32)
# Iteration:  285
# tf.Tensor(160.54454, shape=(), dtype=float32)
# Iteration:  286
# tf.Tensor(160.54556, shape=(), dtype=float32)
# Iteration:  287
# tf.Tensor(160.54106, shape=(), dtype=float32)
# Iteration:  288
# tf.Tensor(160.53966, shape=(), dtype=float32)
# Iteration:  289
# tf.Tensor(160.54413, shape=(), dtype=float32)
# Iteration:  290
# tf.Tensor(160.53716, shape=(), dtype=float32)
# Iteration:  291
# tf.Tensor(160.53897, shape=(), dtype=float32)
# Iteration:  292
# tf.Tensor(160.5389, shape=(), dtype=float32)
# Iteration:  293
# tf.Tensor(160.53772, shape=(), dtype=float32)
# Iteration:  294
# tf.Tensor(160.53912, shape=(), dtype=float32)
# Iteration:  295
# tf.Tensor(160.53482, shape=(), dtype=float32)
# Iteration:  296
# tf.Tensor(160.53387, shape=(), dtype=float32)
# Iteration:  297
# tf.Tensor(160.53545, shape=(), dtype=float32)
# Iteration:  298
# tf.Tensor(160.53172, shape=(), dtype=float32)
# Iteration:  299
# tf.Tensor(160.53456, shape=(), dtype=float32)
# Iteration:  300
# tf.Tensor(160.53354, shape=(), dtype=float32)
# Iteration:  301
# tf.Tensor(160.5303, shape=(), dtype=float32)
# Iteration:  302
# tf.Tensor(160.52579, shape=(), dtype=float32)
# Iteration:  303
# tf.Tensor(160.52835, shape=(), dtype=float32)
# Iteration:  304
# tf.Tensor(160.52599, shape=(), dtype=float32)
# Iteration:  305
# tf.Tensor(160.5239, shape=(), dtype=float32)
# Iteration:  306
# tf.Tensor(160.526, shape=(), dtype=float32)
# Iteration:  307
# tf.Tensor(160.52367, shape=(), dtype=float32)
# Iteration:  308
# tf.Tensor(160.51987, shape=(), dtype=float32)
# Iteration:  309
# tf.Tensor(160.52179, shape=(), dtype=float32)
# Iteration:  310
# tf.Tensor(160.51968, shape=(), dtype=float32)
# Iteration:  311
# tf.Tensor(160.51944, shape=(), dtype=float32)
# Iteration:  312
# tf.Tensor(160.52145, shape=(), dtype=float32)
# Iteration:  313
# tf.Tensor(160.51633, shape=(), dtype=float32)
# Iteration:  314
# tf.Tensor(160.51263, shape=(), dtype=float32)
# Iteration:  315
# tf.Tensor(160.51451, shape=(), dtype=float32)
# Iteration:  316
# tf.Tensor(160.51685, shape=(), dtype=float32)
# Iteration:  317
# tf.Tensor(160.50945, shape=(), dtype=float32)
# Iteration:  318
# tf.Tensor(160.51076, shape=(), dtype=float32)
# Iteration:  319
# tf.Tensor(160.51013, shape=(), dtype=float32)
# Iteration:  320
# tf.Tensor(160.50908, shape=(), dtype=float32)
# Iteration:  321
# tf.Tensor(160.50299, shape=(), dtype=float32)
# Iteration:  322
# tf.Tensor(160.51251, shape=(), dtype=float32)
# Iteration:  323
# tf.Tensor(160.50783, shape=(), dtype=float32)
# Iteration:  324
# tf.Tensor(160.50749, shape=(), dtype=float32)
# Iteration:  325
# tf.Tensor(160.50226, shape=(), dtype=float32)
# Iteration:  326
# tf.Tensor(160.50519, shape=(), dtype=float32)
# Iteration:  327
# tf.Tensor(160.50308, shape=(), dtype=float32)
# Iteration:  328
# tf.Tensor(160.50757, shape=(), dtype=float32)
# Iteration:  329
# tf.Tensor(160.5008, shape=(), dtype=float32)
# Iteration:  330
# tf.Tensor(160.49522, shape=(), dtype=float32)
# Iteration:  331
# tf.Tensor(160.50214, shape=(), dtype=float32)
# Iteration:  332
# tf.Tensor(160.4941, shape=(), dtype=float32)
# Iteration:  333
# tf.Tensor(160.49423, shape=(), dtype=float32)
# Iteration:  334
# tf.Tensor(160.49188, shape=(), dtype=float32)
# Iteration:  335
# tf.Tensor(160.49828, shape=(), dtype=float32)
# Iteration:  336
# tf.Tensor(160.49149, shape=(), dtype=float32)
# Iteration:  337
# tf.Tensor(160.49207, shape=(), dtype=float32)
# Iteration:  338
# tf.Tensor(160.4913, shape=(), dtype=float32)
# Iteration:  339
# tf.Tensor(160.49239, shape=(), dtype=float32)
# Iteration:  340
# tf.Tensor(160.49496, shape=(), dtype=float32)
# Iteration:  341
# tf.Tensor(160.49014, shape=(), dtype=float32)
# Iteration:  342
# tf.Tensor(160.489, shape=(), dtype=float32)
# Iteration:  343
# tf.Tensor(160.48691, shape=(), dtype=float32)
# Iteration:  344
# tf.Tensor(160.48834, shape=(), dtype=float32)
# Iteration:  345
# tf.Tensor(160.48758, shape=(), dtype=float32)
# Iteration:  346
# tf.Tensor(160.48251, shape=(), dtype=float32)
# Iteration:  347
# tf.Tensor(160.48343, shape=(), dtype=float32)
# Iteration:  348
# tf.Tensor(160.48001, shape=(), dtype=float32)
# Iteration:  349
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-92-42a1b4f7f337> in <module>()
#       1 dummy_vox = tf.random.uniform(shape=(32, 32, 32))
#       2
# ----> 3 recover_latent(dummy_vox, 10.0)
#
# <ipython-input-91-01b486eebbb4> in recover_latent(partial, loss_thresh)
#      27     print 'Iteration: ', str(iter)
#      28     # Compute gradient and loss of current latent vector
# ---> 29     gradients, loss = compute_gradients(decoder, curr_latent, partial)
#      30     print loss
#      31     gradients = tf.reshape(gradients, (1, 100))
#
# <ipython-input-91-01b486eebbb4> in compute_gradients(model, latent, partial)
#       8     # model.trainable_variables
#       9     #????? loss is scalar? how is it the gradient target?
# ---> 10     return tape.gradient(loss, latent), loss
#      11
#      12 #
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/eager/backprop.pyc in gradient(self, target, sources, output_gradients, unconnected_gradients)
#     944         flat_sources,
#     945         output_gradients=output_gradients,
# --> 946         unconnected_gradients=unconnected_gradients)
#     947
#     948     if not self._persistent:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/eager/imperative_grad.pyc in imperative_grad(tape, target, sources, output_gradients, unconnected_gradients)
#      70       sources,
#      71       output_gradients,
# ---> 72       compat.as_str(unconnected_gradients.value))
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/eager/backprop.pyc in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads)
#     129     return [None] * num_inputs
#     130
# --> 131   return grad_fn(mock_op, *out_grads)
#     132
#     133
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/nn_grad.pyc in _Conv3DBackpropInputGrad(op, grad)
#     121           strides=op.get_attr("strides"),
#     122           padding=op.get_attr("padding"),
# --> 123           data_format=data_format),
#     124       nn_ops.conv3d(
#     125           grad,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/gen_nn_ops.pyc in conv3d_backprop_filter_v2(input, filter_sizes, out_backprop, strides, padding, data_format, dilations, name)
#    1639         "Conv3DBackpropFilterV2", name, _ctx._post_execution_callbacks, input,
#    1640         filter_sizes, out_backprop, "strides", strides, "padding", padding,
# -> 1641         "data_format", data_format, "dilations", dilations)
#    1642       return _result
#    1643     except _core._FallbackException:
#
# KeyboardInterrupt:
